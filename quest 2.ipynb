# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def get_product_details(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extracting product details
    try:
        brand_name = soup.find('span', class_='brand-name').text.strip()
    except AttributeError:
        brand_name = '-'
    
    try:
        product_name = soup.find('h1', class_='product-name').text.strip()
    except AttributeError:
        product_name = '-'
    
    try:
        price = soup.find('span', class_='price').text.strip()
    except AttributeError:
        price = '-'
    
    try:
        return_exchange = soup.find('div', class_='return-exchange').text.strip()
    except AttributeError:
        return_exchange = '-'
    
    try:
        expected_delivery = soup.find('div', class_='expected-delivery').text.strip()
    except AttributeError:
        expected_delivery = '-'
    
    try:
        availability = soup.find('div', class_='availability').text.strip()
    except AttributeError:
        availability = '-'
    
    return {
        'Brand Name': brand_name,
        'Product Name': product_name,
        'Price': price,
        'Return/Exchange': return_exchange,
        'Expected Delivery': expected_delivery,
        'Availability': availability,
        'Product URL': url
    }

def scrape_search_results():
    base_url = 'your_base_search_url_here'
    all_product_details = []
    
    # Loop through the first 3 pages
    for page_num in range(1, 4):
        page_url = f'{base_url}&page={page_num}'
        response = requests.get(page_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract product URLs from the page
        product_links = [a['href'] for a in soup.find_all('a', class_='product-link')]
        
        # Loop through each product URL and get details
        for link in product_links:
            product_details = get_product_details(link)
            all_product_details.append(product_details)
            
        time.sleep(2)  # Add a delay to avoid overwhelming the server
        
    return all_product_details

# Scraping the data
product_details = scrape_search_results()

# Creating a DataFrame
df = pd.DataFrame(product_details)

# Saving to CSV
df.to_csv('product_details.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[1], line 76
#      73     return all_product_details
#      75 # Scraping the data
# ---> 76 product_details = scrape_search_results()
#      78 # Creating a DataFrame
#      79 df = pd.DataFrame(product_details)
#
# Cell In[1], line 60, in scrape_search_results()
#      58 for page_num in range(1, 4):
#      59     page_url = f'{base_url}&page={page_num}'
# ---> 60     response = requests.get(page_url)
#      61     soup = BeautifulSoup(response.content, 'html.parser')
#      63     # Extract product URLs from the page
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
# ...
